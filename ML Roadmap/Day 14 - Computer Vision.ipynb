# %%
import tensorflow as tf
(xtrain,ytrain),(xtest,ytest)=tf.keras.datasets.mnist.load_data()

# %%
xtrain.shape,ytrain.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
ytrain
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
xtrain[0].shape
# Out:
# (28, 28)

# %%
import matplotlib.pyplot as plt
def drawing(sample):
    plt.imshow(sample)

drawing(xtrain[110])

# %%
ytrain[110]
# Out:
# 9

# %%
xtrain=xtrain/255
xtest=xtest/255

# %%
import keras

model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(64,activation='sigmoid'),
    keras.layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(xtrain,ytrain,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.3160 - accuracy: 0.9173
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1175 - accuracy: 0.9654
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0791 - accuracy: 0.9765
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0572 - accuracy: 0.9828
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0438 - accuracy: 0.9863
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0338 - accuracy: 0.9897
# Epoch 7/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0273 - accuracy: 0.9915
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0221 - accuracy: 0.9931
# Epoch 9/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0180 - accuracy: 0.9946
# Epoch 10/10
# ...

# %%
model.save('digitmodel.model')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: digitmodel.model\assets
# INFO:tensorflow:Assets written to: digitmodel.model\assets

# %%
pred=model.predict(xtest)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
pred
# Out:
# array([[2.2306561e-07, 3.2014290e-07, 2.4517678e-06, ..., 9.9999034e-01,
#         2.0167026e-07, 3.7722932e-06],
#        [6.6892460e-07, 1.8916604e-05, 9.9992907e-01, ..., 1.1690626e-07,
#         4.0143113e-05, 3.2201215e-09],
#        [1.3032421e-07, 9.9996984e-01, 1.5147227e-05, ..., 8.7554135e-06,
#         2.1544517e-06, 5.0456407e-08],
#        ...,
#        [1.2096163e-09, 1.8143787e-06, 8.8254897e-09, ..., 5.1295760e-06,
#         2.9275270e-07, 6.3147214e-05],
#        [2.7045937e-07, 9.2978167e-09, 8.0677239e-08, ..., 1.8432804e-09,
#         2.6365847e-04, 1.1066110e-06],
#        [9.4949917e-07, 5.7012723e-08, 1.8220241e-08, ..., 8.8715196e-10,
#         5.2352584e-07, 1.9609483e-09]], dtype=float32)

# %%
import numpy as np
pred_value=[]
for x in pred:
    pred_value.append(np.argmax(x))

# %%
pred_value
# Out:
# [7,
#  2,
#  1,
#  0,
#  4,
#  1,
#  4,
#  9,
#  6,
#  9,
#  0,
#  6,
#  9,
#  0,
#  1,
#  5,
#  9,
#  7,
#  3,
#  4,
#  9,
#  6,
#  6,
#  5,
#  4,
#  0,
#  7,
#  4,
#  0,
#  1,
#  3,
#  1,
#  3,
#  4,
#  7,
#  2,
#  7,
#  1,
#  2,
#  1,
#  1,
#  7,
#  4,
#  2,
#  3,
#  5,
#  1,
#  2,
#  4,
#  4,
#  6,
#  3,
#  5,
#  5,
#  6,
#  0,
#  4,
#  1,
#  9,
#  5,
#  7,
#  8,
#  9,
#  3,
#  7,
#  4,
#  6,
#  4,
#  3,
#  0,
#  7,
#  0,
#  2,
#  9,
#  1,
#  7,
#  3,
#  2,
#  9,
#  7,
#  7,
#  6,
#  2,
#  7,
#  8,
#  4,
#  7,
#  3,
#  6,
#  1,
#  3,
#  6,
#  9,
#  3,
#  1,
#  4,
#  1,
#  7,
#  6,
#  9,
#  6,
#  0,
#  5,
#  4,
#  5,
#  9,
#  2,
#  1,
#  9,
#  4,
#  8,
#  7,
#  3,
#  9,
#  7,
#  4,
#  4,
#  4,
#  9,
#  2,
#  5,
#  4,
#  7,
#  6,
#  7,
#  9,
#  0,
#  5,
#  8,
#  5,
#  6,
#  6,
#  5,
#  7,
#  8,
#  1,
#  0,
#  1,
#  6,
#  4,
#  6,
#  7,
#  3,
#  1,
#  7,
#  1,
#  8,
#  2,
#  0,
#  2,
#  9,
#  9,
#  5,
#  5,
#  1,
#  5,
#  6,
#  0,
#  3,
#  4,
#  4,
#  6,
#  5,
#  4,
#  6,
#  5,
# ...

# %%
for x,y in zip(pred_value,ytest):
    print(f"pred: {x} and actual {y}")
# Out:
# pred: 7 and actual 7
# pred: 2 and actual 2
# pred: 1 and actual 1
# pred: 0 and actual 0
# pred: 4 and actual 4
# pred: 1 and actual 1
# pred: 4 and actual 4
# pred: 9 and actual 9
# pred: 6 and actual 5
# pred: 9 and actual 9
# pred: 0 and actual 0
# pred: 6 and actual 6
# pred: 9 and actual 9
# pred: 0 and actual 0
# pred: 1 and actual 1
# pred: 5 and actual 5
# pred: 9 and actual 9
# pred: 7 and actual 7
# pred: 3 and actual 3
# pred: 4 and actual 4
# pred: 9 and actual 9
# pred: 6 and actual 6
# pred: 6 and actual 6
# pred: 5 and actual 5
# pred: 4 and actual 4
# pred: 0 and actual 0
# pred: 7 and actual 7
# pred: 4 and actual 4
# pred: 0 and actual 0
# pred: 1 and actual 1
# pred: 3 and actual 3
# pred: 1 and actual 1
# pred: 3 and actual 3
# pred: 4 and actual 4
# pred: 7 and actual 7
# pred: 2 and actual 2
# pred: 7 and actual 7
# pred: 1 and actual 1
# pred: 2 and actual 2
# pred: 1 and actual 1
# pred: 1 and actual 1
# pred: 7 and actual 7
# pred: 4 and actual 4
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred_value,ytest)
# Out:
# 0.9776

# %%
from skimage.io import imread,imshow
image=imread('dataset/1.jpg',as_gray=True)
imshow(image)

# %%
image.shape
# Out:
# (152, 152)

# %%
image=image/255

# %%
image.shape
# Out:
# (152, 152)

# %%
from skimage.transform import resize
re_image=resize(image,(28,28))
imshow(re_image)
# Out:
# C:\Users\Dell\anaconda3\envs\aiproject\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
new_image_pred=model.predict(re_image)
# Out:
# 1/1 [==============================] - 0s 89ms/step

# %%
np.argmax(new_image_pred)
# Out:
# 5

# %%
new_image_pred
# Out:
# array([[0.0104082 , 0.17676048, 0.07448424, 0.00700421, 0.10229311,
#         0.34298855, 0.06961306, 0.0876468 , 0.09119345, 0.03760793]],
#       dtype=float32)

# %%
#Cifar dataset
cifar10 = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
drawing(x_train[1])

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
class_names =['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i][0]])

# %%
x_train.shape,x_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
model=tf.keras.models.Sequential() #functional
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(64,activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(256,activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))

# %%
model=tf.keras.models.Sequential() #functional
model.add(tf.keras.layers.Conv2D(32,(3,3),activation=tf.nn.relu,input_shape=(32,32,3)))
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Conv2D(128,(3,3),activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Conv2D(256,(3,3),activation=tf.nn.relu))
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=2)
# Out:
# Epoch 1/2
# 1563/1563 [==============================] - 200s 126ms/step - loss: 2.2862 - accuracy: 0.3381
# Epoch 2/2
# 1563/1563 [==============================] - 201s 129ms/step - loss: 1.4810 - accuracy: 0.4643

# %%
pred_value=model.predict(x_test)
# Out:
# 313/313 [==============================] - 8s 24ms/step

# %%
value=[]
for x in pred_value:
    value.append(np.argmax(x))
value
# Out:
# [8,
#  1,
#  8,
#  8,
#  6,
#  6,
#  1,
#  6,
#  3,
#  1,
#  0,
#  9,
#  7,
#  7,
#  9,
#  6,
#  3,
#  7,
#  9,
#  6,
#  7,
#  2,
#  2,
#  1,
#  4,
#  4,
#  4,
#  6,
#  9,
#  6,
#  6,
#  5,
#  2,
#  3,
#  9,
#  9,
#  7,
#  1,
#  9,
#  5,
#  8,
#  6,
#  7,
#  6,
#  0,
#  9,
#  3,
#  9,
#  7,
#  6,
#  9,
#  8,
#  6,
#  3,
#  8,
#  8,
#  7,
#  9,
#  3,
#  3,
#  7,
#  5,
#  1,
#  3,
#  6,
#  2,
#  1,
#  0,
#  5,
#  7,
#  4,
#  6,
#  8,
#  8,
#  9,
#  4,
#  9,
#  3,
#  3,
#  8,
#  8,
#  1,
#  1,
#  7,
#  2,
#  7,
#  2,
#  8,
#  9,
#  9,
#  8,
#  4,
#  8,
#  6,
#  7,
#  6,
#  6,
#  0,
#  0,
#  7,
#  3,
#  7,
#  6,
#  3,
#  1,
#  1,
#  2,
#  6,
#  9,
#  5,
#  5,
#  0,
#  2,
#  2,
#  1,
#  6,
#  0,
#  7,
#  3,
#  3,
#  8,
#  7,
#  1,
#  4,
#  8,
#  6,
#  8,
#  3,
#  3,
#  0,
#  4,
#  1,
#  8,
#  9,
#  1,
#  2,
#  9,
#  2,
#  4,
#  8,
#  3,
#  5,
#  6,
#  3,
#  8,
#  3,
#  3,
#  6,
#  7,
#  3,
#  9,
#  9,
#  6,
#  1,
#  0,
#  3,
#  3,
#  9,
#  3,
#  4,
#  2,
#  1,
#  9,
#  6,
#  8,
#  4,
# ...

# %%
for x,y in zip(value,ytest):
    print(f"pred {x} actual {y}")
# Out:
# pred 8 actual 7
# pred 1 actual 2
# pred 8 actual 1
# pred 8 actual 0
# pred 6 actual 4
# pred 6 actual 1
# pred 1 actual 4
# pred 6 actual 9
# pred 3 actual 5
# pred 1 actual 9
# pred 0 actual 0
# pred 9 actual 6
# pred 7 actual 9
# pred 7 actual 0
# pred 9 actual 1
# pred 6 actual 5
# pred 3 actual 9
# pred 7 actual 7
# pred 9 actual 3
# pred 6 actual 4
# pred 7 actual 9
# pred 2 actual 6
# pred 2 actual 6
# pred 1 actual 5
# pred 4 actual 4
# pred 4 actual 0
# pred 4 actual 7
# pred 6 actual 4
# pred 9 actual 0
# pred 6 actual 1
# pred 6 actual 3
# pred 5 actual 1
# pred 2 actual 3
# pred 3 actual 4
# pred 9 actual 7
# pred 9 actual 2
# pred 7 actual 7
# pred 1 actual 1
# pred 9 actual 2
# pred 5 actual 1
# pred 8 actual 1
# pred 6 actual 7
# pred 7 actual 4
# pred 6 actual 2
# pred 0 actual 3
# pred 9 actual 5
# pred 3 actual 1
# pred 9 actual 2
# pred 7 actual 4
# pred 6 actual 4
# pred 9 actual 6
# pred 8 actual 3
# pred 6 actual 5
# pred 3 actual 5
# pred 8 actual 6
# ...

# %%
#Cats and Dog
#Custom dataset

import os
import zipfile
import tensorflow as tf

location='dataset/kagglecatsanddogs_5340.zip'
zip_ref=zipfile.ZipFile(location,'r')
zip_ref.extractall('dataset/')
zip_ref.close()

# %%
len(os.listdir('dataset/PetImages/Cat/'))
# Out:
# 12501

# %%
len(os.listdir('dataset/PetImages/Dog/'))
# Out:
# 12501
