# %%
import pandas as pd
df=pd.read_csv('dataset/Sales_Data/alldf.csv')
df
# Out:
#         Unnamed: 0  Order ID                     Product  Quantity Ordered  \
# 0                0    176558        USB-C Charging Cable                 2
# 1                2    176559  Bose SoundSport Headphones                 1
# 2                3    176560                Google Phone                 1
# 3                4    176560            Wired Headphones                 1
# 4                5    176561            Wired Headphones                 1
# ...            ...       ...                         ...               ...
# 185945       17656    295660      AAA Batteries (4-pack)                 2
# 185946       17657    295661        USB-C Charging Cable                 1
# 185947       17658    295662    Lightning Charging Cable                 1
# 185948       17659    295663      AAA Batteries (4-pack)                 1
# 185949       17660    295664                Google Phone                 1
#
# ...

# %%
df['Sales Amount'].sum()
# Out:
# 34492035.97

# %%
df['Product'].nunique()
# Out:
# 19

# %%
month='November'
city='Boston'
product=['Google Phone','Lightning Charging Cable']

df_selection=df.query("Product==@product and Month==@month and City==@city")
df_selection
# Out:
#         Unnamed: 0  Order ID                   Product  Quantity Ordered  \
# 168423          53    278845  Lightning Charging Cable                 1
# 168485         116    278906  Lightning Charging Cable                 1
# 168534         166    278951  Lightning Charging Cable                 1
# 168571         203    278987  Lightning Charging Cable                 1
# 168589         221    279005  Lightning Charging Cable                 1
# ...            ...       ...                       ...               ...
# 185769       17480    295488  Lightning Charging Cable                 1
# 185817       17528    295534              Google Phone                 1
# 185825       17536    295541  Lightning Charging Cable                 1
# 185947       17658    295662  Lightning Charging Cable                 1
# 185949       17660    295664              Google Phone                 1
#
#         Price Each           Order Date                  Purchase Address  \
# ...

# %%
df_selection.groupby('Product')['Sales Amount'].sum().sort_values(ascending=False)
# Out:
# Product
# Google Phone                28800.00
# Lightning Charging Cable     3842.15
# Name: Sales Amount, dtype: float64

# %%
sales_by_month=df_selection.groupby('Month')['Sales Amount'].sum().sort_values(ascending=False)
sales_by_month
# Out:
# Month
# November    32642.15
# Name: Sales Amount, dtype: float64
